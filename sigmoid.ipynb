# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
x = np.linspace(-10.0, 10.0)
y = [sigmoid(z) for z in x]

# %%
plt.plot(x, y)
plt.grid()
plt.show()
